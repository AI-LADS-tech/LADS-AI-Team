# %%
#Importing neccesary libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading the file
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
plt.plot(train['Ticket'],train['Age'])
plt.show()

# %%
plt.scatter(train['Ticket'],train['Age'] ,alpha=0.5)
sizes = 10 * np.random.randint(100, size=(100))
plt.colorbar()

colors = np.random.randint(100, size=(100))
plt.show()

# %%
#plt.bar(train['Ticket'],train['Age'] ,alpha=0.5)
plt.bar(test['Ticket'],test['Age'] ,color = 'red', width = 0.1)

plt.ylabel('AGE')
plt.xlabel('Tickets')


plt.show()

# %%
#HISTOGRAM
plt.hist(train['Age'])
plt.show()

# %%
train['Age'].mean()
# Out:
# 29.69911764705882

# %%
#pie chart 
x=np.array([12,35,67,45])
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e4d47d8b80>,
#   <matplotlib.patches.Wedge at 0x1e4d47d8760>,
#   <matplotlib.patches.Wedge at 0x1e4d667c070>,
#   <matplotlib.patches.Wedge at 0x1e4d667cca0>],
#  [Text(1.0692252045755923, 0.25837465413674576, ''),
#   Text(0.4334692891330088, 1.0109917780964017, ''),
#   Text(-1.0991412416195931, -0.04345723151489604, ''),
#   Text(0.6930965766359644, -0.8541762906189254, '')])
