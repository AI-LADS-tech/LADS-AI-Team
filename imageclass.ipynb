# %%
 import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# %matplotlib inline
import matplotlib.image as mpimg
# Out:
# 2.4.0

# %%
#getting dataset from keras 
fashion_mnist=tf.keras.datasets.fashion_mnist

(train_image,train_labels),(test_images,test_labels)=fashion_mnist.load_data()
train_image.shape
# Out:
# (60000, 28, 28)

# %%
#label the data
class_names=['T-Shirts/top','trouser','pullover','dress','coat','sandal','shirt','sneaker','bag','ankle boot']

# %%
#finding the length training and testing dta 
len(train_labels)
train_labels
test_images.shape
len(test_labels)
# Out:
# 10000

# %%
#ploting the images
plt.figure()
plt.imshow(train_image[339])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
#normalize the data
train_image=train_image / 255.0
test_images=test_images / 255.0

# %%
#plot again 
plt.figure(figsize=(10,10))
for i in range(10):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(train_image[i] , cmap=plt.cm.binary)
  plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
# model building
model=tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28,28,1)),
                           tf.keras.layers.Dense(128, activation=tf.nn.relu),
                           tf.keras.layers.Dense(10,activation=tf.nn.softmax)
                           ])

# %%
#compile model
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
#model training]
model.fit(train_image, train_labels, epochs=10)
model.fit(train_image, train_labels, epochs=10)

#evaluate the model
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(),metrics=['accuracy'])

test_loss, test_acc=model.evaluate(test_images , test_labels , verbose=2)

print('test accurarcy ' , test_acc)
probability_model=tf.keras.Sequential([model,tf.keras.layers.Softmax()])
predictions=probability_model.predict(test_images)
predictions[0]
test_labels[0]
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1757 - accuracy: 0.9344
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1682 - accuracy: 0.9370
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1659 - accuracy: 0.9383
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1602 - accuracy: 0.9393
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1580 - accuracy: 0.9414
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1527 - accuracy: 0.9423
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1506 - accuracy: 0.9435
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1471 - accuracy: 0.9451
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1446 - accuracy: 0.9463
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1399 - accuracy: 0.9477
# Epoch 1/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1389 - accuracy: 0.9475
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1352 - accuracy: 0.9486
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1328 - accuracy: 0.9509
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1276 - accuracy: 0.9522
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1279 - accuracy: 0.9517
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1234 - accuracy: 0.9540
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1218 - accuracy: 0.9538
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1201 - accuracy: 0.9545
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1160 - accuracy: 0.9567
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1157 - accuracy: 0.9567
# 313/313 - 0s - loss: 0.4668 - accuracy: 0.8781
# test accurarcy  0.8780999779701233
# 9

# %%
# Out:
# 313/313 - 0s - loss: 0.3609 - accuracy: 0.8867
# test accurarcy  0.8866999745368958
# 9
